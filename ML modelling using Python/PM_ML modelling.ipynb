# %% [markdown]
# # PM

# %%
#method1
#Support Vecctor Regression
#1 Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#2 Importing the dataset
# dataset = pd.read_csv(r'C:\Users\shubh\Desktop\IITM\Courses\Sem 2\ML in civil eng\term paper\CE6051- vehicular emission data set - Sheet12.csv')
dataset = pd.read_csv(r'C:\Users\shubh\Desktop\IITM\Courses\Sem 2\ML in civil eng\term paper\vehicularemission_modified2_PM.csv')
#dataset = dataset[dataset["PM emissions (g/km)"]<0.02]
X = dataset.iloc[1:,0:5].values.astype(float)
y = dataset.iloc[1:,6:7].values.astype(float)
print(y)

#3 selecting training dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

#4 Fitting the Support Vector Regression Model to the dataset
# Create your support vector regressor here
from sklearn.svm import SVR
# most important SVR parameter is Kernel type. It can be linear,polynomial or gaussian.
#SVR. We have a non-linear condition so we can select polynomial or gaussian but here
#we select RBF(a gaussian type) while here I substituted it with 'linear' kernel. 
regressor = SVR(kernel='linear')
regressor.fit(X_train, y_train, sample_weight = None)

#5 finding results
y_pred = regressor.predict(X_test)
y_pred


dataset.shape
# Out:
# [[2.0e-02]
#  [2.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [8.0e-02]
#  [8.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [8.0e-02]
#  [8.0e-02]
#  [8.0e-02]
#  [8.0e-02]
#  [1.2e-01]
#  [7.0e-02]
#  [7.0e-02]
#  [1.0e-01]
#  [7.0e-02]
#  [5.0e-02]
#  [7.0e-02]
#  [7.0e-02]
#  [3.0e-02]
#  [1.0e-02]
#  [1.0e-02]
#  [1.6e-01]
#  [5.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [0.0e+00]
#  [4.0e-02]
#  [4.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [0.0e+00]
#  [7.0e-02]
#  [4.0e-02]
#  [7.0e-02]
#  [9.0e-02]
#  [9.0e-02]
#  [4.0e-02]
#  [3.0e-02]
#  [5.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [2.0e-04]
#  [3.0e-02]
#  [3.0e-02]
#  [8.0e-02]
#  [8.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [2.0e-04]
#  [1.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [7.0e-02]
#  [6.0e-02]
#  [6.0e-02]
#  [2.0e-02]
#  [0.0e+00]
#  [2.0e-02]
#  [5.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [7.0e-02]
#  [0.0e+00]
#  [2.0e-02]
#  [4.0e-01]
#  [0.0e+00]
#  [0.0e+00]
#  [3.0e-02]
#  [4.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [8.0e-02]
#  [8.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [2.0e-02]
#  [0.0e+00]
#  [1.0e-02]
#  [2.0e-02]
#  [5.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [2.0e-01]
#  [3.0e-02]
#  [4.0e-02]
#  [9.0e-01]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [1.0e-02]
#  [2.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [0.0e+00]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [0.0e+00]
#  [4.0e-02]
#  [0.0e+00]
#  [3.0e-02]
#  [0.0e+00]
#  [9.0e-02]
#  [0.0e+00]
#  [1.6e+00]
#  [0.0e+00]
#  [0.0e+00]
#  [4.0e-02]
#  [0.0e+00]
#  [4.0e-01]
#  [0.0e+00]
#  [0.0e+00]
#  [9.0e-01]
#  [2.0e-02]
#  [4.0e-01]
#  [5.0e-02]
#  [5.0e-02]
#  [5.0e-02]
#  [0.0e+00]
#  [3.0e-03]
#  [3.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-01]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [4.0e-01]
#  [3.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [2.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [4.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [1.0e-02]
#  [1.3e-01]
#  [4.0e-02]
#  [0.0e+00]
#  [4.0e-02]
#  [4.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [0.0e+00]
#  [3.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [3.0e-02]
#  [2.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [3.0e-02]
#  [2.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [3.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [1.0e+00]
#  [4.0e-02]
#  [2.0e-02]
#  [1.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [3.0e-02]
#  [3.0e-02]
#  [2.0e-02]
#  [1.0e+00]
#  [1.0e-02]
#  [0.0e+00]
#  [1.0e+00]
#  [1.0e+00]
#  [2.0e-01]
#  [1.2e+00]
#  [2.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [1.0e-02]
#  [3.0e-03]
#  [2.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [1.2e-01]
#  [2.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [1.0e-03]
#  [1.0e-03]
#  [1.0e-02]
#  [3.0e-02]
#  [4.0e-02]
#  [4.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [2.0e-02]
#  [2.0e-02]
#  [1.0e-02]
#  [1.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [4.0e-02]
#  [0.0e+00]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [4.0e-02]
#  [2.0e-02]
#  [8.0e-04]
#  [0.0e+00]
#  [4.0e-02]
#  [3.0e-02]
#  [2.1e-01]
#  [0.0e+00]
#  [0.0e+00]
#  [2.0e-02]
#  [2.0e-04]
#  [2.0e-02]
#  [1.0e-02]
#  [1.2e-01]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [0.0e+00]
#  [0.0e+00]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [2.0e-02]
#  [3.0e-02]
#  [1.0e+00]
#  [2.0e-02]
#  [4.0e-02]
#  [4.0e-01]
#  [0.0e+00]
#  [2.0e-02]
#  [0.0e+00]
#  [1.0e-04]
#  [1.0e+00]
#  [1.0e+00]
#  [2.0e-02]
#  [1.0e+00]
#  [1.0e+00]
#  [0.0e+00]
#  [1.0e-02]
#  [2.0e-02]
#  [1.0e+00]
#  [1.0e+00]
#  [1.0e-04]
#  [1.0e-04]
#  [1.0e-04]
#  [6.0e-01]
#  [1.0e+00]
#  [1.0e+00]
#  [1.0e+00]
#  [1.0e+00]
#  [0.0e+00]]
# C:\Users\shubh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (353, 11)

# %%
#6 obtaining plots 
plt.scatter(y_test, y_pred, color = 'black')
plt.title('y_pred vs y_test')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %%
#weight vector
w = regressor.coef_
w
# Out:
# array([[ 1.45471225e-03,  7.72093222e-03, -1.62447795e-02,
#          5.87440927e-15, -6.75390394e-03]])

# %%
regressor.score(X, y, sample_weight = None)
# Out:
# 0.009542964052525416

# %%
#Multiple Linear Regression
#6 Fit multiple Linear Regression model to our Train set
from sklearn.linear_model import LinearRegression
#Create an object called regressor in the LinearRegression class...
regr = LinearRegression()
#Fit the linear regression model to the training set... We use the fit method
#the arguments of the fit method will be training sets 
regr.fit(X_train,y_train)

#7 Predicting the Test set results: 
y_pred= regr.predict(X_test)
y_pred
# Out:
# array([[ 0.06987418],
#        [ 0.05888201],
#        [ 0.05135052],
#        [ 0.13421744],
#        [ 0.13033026],
#        [ 0.05780725],
#        [ 0.15523333],
#        [ 0.13053072],
#        [ 0.02099544],
#        [ 0.11348703],
#        [ 0.23325887],
#        [ 0.04992951],
#        [ 0.12439712],
#        [ 0.00688751],
#        [ 0.06849121],
#        [ 0.02462233],
#        [ 0.10038271],
#        [ 0.09756762],
#        [ 0.29781898],
#        [ 0.12601948],
#        [ 0.07238065],
#        [ 0.14145145],
#        [-0.00130386],
#        [ 0.08487469],
#        [-0.03865057],
#        [ 0.13293793],
#        [-0.04476077],
#        [ 0.04756882],
#        [ 0.09477745],
#        [ 0.17482239],
#        [ 0.01250507],
#        [-0.07909028],
#        [ 0.02542782],
#        [-0.01310293],
#        [ 0.09563061],
#        [-0.05427846],
#        [ 0.03302156],
#        [ 0.070835  ],
#        [ 0.09308107],
#        [ 0.06490286],
#        [ 0.15243493],
#        [ 0.14895668],
#        [ 0.0225154 ],
#        [ 0.11081589],
#        [ 0.17267809],
#        [ 0.04602318],
#        [-0.05427846],
#        [ 0.17276723],
#        [ 0.05500529],
#        [ 0.28591131],
#        [ 0.1047325 ],
#        [ 0.06298232],
#        [ 0.13919333],
#        [ 0.087609  ],
#        [ 0.0302399 ],
#        [ 0.00889351],
#        [ 0.16850692],
#        [ 0.06908535],
#        [ 0.06956554],
#        [-0.02911424],
#        [ 0.10368428],
#        [ 0.13585236],
#        [ 0.14323993],
#        [ 0.13720844],
#        [ 0.07869655],
#        [ 0.07012503],
#        [ 0.06083971],
#        [ 0.02283815],
#        [ 0.08308577],
#        [-0.07683466],
#        [ 0.01055353]])

# %%
#6 obtaining plots 
plt.scatter(y_test, y_pred, color = 'black')
plt.title('y_pred vs y_test')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %%
regr.score(X_test,y_test)
# Out:
# 0.13256264631084946

# %%
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
model=sm.OLS(y_train,X_train).fit()
predictions=model.predict(X_train)
results=model.summary()
print(results)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     7.530
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):           1.21e-06
# Time:                        00:08:03   Log-Likelihood:                 11.566
# No. Observations:                 281   AIC:                            -11.13
# Df Residuals:                     275   BIC:                             10.70
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0261      0.146      0.178      0.859      -0.262       0.314
# x1            -0.0794      0.016     -4.891      0.000      -0.111      -0.047
# x2             0.0272      0.029      0.928      0.354      -0.031       0.085
# x3            -0.0506      0.029     -1.745      0.082      -0.108       0.006
# x4            -0.0415      0.115     -0.362      0.717      -0.267       0.184
# x5            -0.0267      0.017     -1.569      0.118      -0.060       0.007
# ==============================================================================
# Omnibus:                      189.183   Durbin-Watson:                   1.744
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1408.863
# Skew:                           2.812   Prob(JB):                    1.17e-306
# Kurtosis:                      12.418   Cond. No.                         23.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api  as sm 
#The 0th column contains only 1 in each 352 rows 
#X_train= np.append(arr = np.ones((544,1)).astype(int), values = X_train, axis=1) 
X_opt= X_train[:,[1,2,3,4,5]] #Optimal X contains the highly impacted independent variables
#OLS: Oridnary Least Square Class. endog is the dependent variable, exog is the number of observations
regressor_OLS=sm.OLS(endog = y_train, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     17.92
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):           2.18e-15
# Time:                        00:09:06   Log-Likelihood:                 11.550
# No. Observations:                 281   AIC:                            -13.10
# Df Residuals:                     276   BIC:                             5.093
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0793      0.016     -4.897      0.000      -0.111      -0.047
# x2             0.0273      0.029      0.932      0.352      -0.030       0.085
# x3            -0.0509      0.029     -1.765      0.079      -0.108       0.006
# x4            -0.0617      0.015     -4.009      0.000      -0.092      -0.031
# x5            -0.0267      0.017     -1.572      0.117      -0.060       0.007
# ==============================================================================
# Omnibus:                      188.965   Durbin-Watson:                   1.744
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1404.727
# Skew:                           2.808   Prob(JB):                    9.28e-306
# Kurtosis:                      12.404   Cond. No.                         4.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_opt= X_train[:,[1,3,4,5]] #Optimal X contains the highly impacted independent variables
#OLS: Oridnary Least Square Class. endog is the dependent variable, exog is the number of observations
regressor_OLS=sm.OLS(endog = y_train, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     22.20
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):           6.55e-16
# Time:                        00:09:51   Log-Likelihood:                 11.108
# No. Observations:                 281   AIC:                            -14.22
# Df Residuals:                     277   BIC:                            0.3374
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0801      0.016     -4.953      0.000      -0.112      -0.048
# x2            -0.0301      0.018     -1.652      0.100      -0.066       0.006
# x3            -0.0702      0.012     -5.628      0.000      -0.095      -0.046
# x4            -0.0248      0.017     -1.475      0.141      -0.058       0.008
# ==============================================================================
# Omnibus:                      190.017   Durbin-Watson:                   1.741
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1433.120
# Skew:                           2.822   Prob(JB):                         0.00
# Kurtosis:                      12.515   Cond. No.                         2.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_opt= X_train[:,[1,3,4]] #Optimal X contains the highly impacted independent variables
#OLS: Oridnary Least Square Class. endog is the dependent variable, exog is the number of observations
regressor_OLS=sm.OLS(endog = y_train, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     28.75
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):           3.20e-16
# Time:                        00:10:18   Log-Likelihood:                 10.009
# No. Observations:                 281   AIC:                            -14.02
# Df Residuals:                     278   BIC:                            -3.104
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0778      0.016     -4.823      0.000      -0.109      -0.046
# x2            -0.0215      0.017     -1.244      0.215      -0.055       0.013
# x3            -0.0692      0.012     -5.547      0.000      -0.094      -0.045
# ==============================================================================
# Omnibus:                      192.543   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1503.843
# Skew:                           2.856   Prob(JB):                         0.00
# Kurtosis:                      12.789   Cond. No.                         2.08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_opt= X_train[:,[1,4]] #Optimal X contains the highly impacted independent variables
#OLS: Oridnary Least Square Class. endog is the dependent variable, exog is the number of observations
regressor_OLS=sm.OLS(endog = y_train, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     42.27
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):           9.25e-17
# Time:                        00:10:58   Log-Likelihood:                 9.2295
# No. Observations:                 281   AIC:                            -14.46
# Df Residuals:                     279   BIC:                            -7.182
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0855      0.015     -5.742      0.000      -0.115      -0.056
# x2            -0.0766      0.011     -6.963      0.000      -0.098      -0.055
# ==============================================================================
# Omnibus:                      194.445   Durbin-Watson:                   1.708
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1529.860
# Skew:                           2.892   Prob(JB):                         0.00
# Kurtosis:                      12.860   Cond. No.                         1.36
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Multiple Linear Regression Model 
#We will on modelling how R&D, Administration and Marketing Spending and the state will
#influence the profit of a company. There are 50 startups data in dataset.

#1 Importing the libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

#2 Importing the dataset: 
dataset = pd.read_csv(r'C:\Users\shubh\Desktop\IITM\Courses\Sem 2\ML in civil eng\term paper\vehicularemission_modified2.csv')
#Y: dependent variable vector
#In the first run X's type is object due to the different types of independent variables. 
#State column contains categorical variables
X = dataset.iloc[1:,1:5].values.astype(float)
y = dataset.iloc[1:,5:6].values.astype(float)

#3 Encoding the categorical variables: 
#from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#labelencoder_X = LabelEncoder() #Change the text into numbers 0,1,2
#X[: ,3]= labelencoder_X.fit_transform(X[: ,3])
#onehotencoder= OneHotEncoder(categorical_features=[3])
#turn the numbers to dummy variables. Each column represents one state
#Compare the X and dataset tables to understand the relationship between the state and the columns 
#X= onehotencoder.fit_transform(X).toarray()

#4 Avoid the dummy variables trap
#Delete the first column represent the California 
#X= X[:, 1:]

#5 Splitting the dataset into the Training and Test dataset
#train_set_split: Split arrays or matrices into random train and test subsets
##random_state değeri sonuçların her seferinde aynı çıkmasını sağlamak için kullanılıyor.
#%20 of the dataset to the test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=0)

#6 Fit multiple Linear Regression model to our Train set
from sklearn.linear_model import LinearRegression
#Create an object called regressor in the LinearRegression class...
regressor = LinearRegression()
#Fit the linear regression model to the training set... We use the fit method
#the arguments of the fit method will be training sets 
regressor.fit(X_train,y_train)

#7 Predicting the Test set results: 
y_pred= regressor.predict(X_test)
y_pred
# Out:
# array([[0.01242553],
#        [0.04996308],
#        [0.14470677],
#        [0.05062879],
#        [0.1248504 ],
#        [0.13756307],
#        [0.08670183],
#        [0.11724999],
#        [0.09382301],
#        [0.07320035],
#        [0.15602362],
#        [0.06776343],
#        [0.13931304],
#        [0.07284738],
#        [0.14246001],
#        [0.10666051],
#        [0.08018423],
#        [0.13530969],
#        [0.19377113],
#        [0.13530969],
#        [0.13268122],
#        [0.14263786],
#        [0.00379377],
#        [0.17546696],
#        [0.11746657],
#        [0.05046401],
#        [0.09395879],
#        [0.14056097],
#        [0.05487799],
#        [0.14423353],
#        [0.06214051],
#        [0.08620669],
#        [0.01232562],
#        [0.09380626],
#        [0.05101131],
#        [0.0561337 ],
#        [0.20233402],
#        [0.11746657],
#        [0.13931304],
#        [0.03455808],
#        [0.15761928],
#        [0.09147987],
#        [0.14916869],
#        [0.14566938],
#        [0.07500963],
#        [0.08793227],
#        [0.07497801],
#        [0.12213679],
#        [0.12855265],
#        [0.17567981],
#        [0.13931304],
#        [0.08770935],
#        [0.12902775],
#        [0.01242553],
#        [0.02866528],
#        [0.15459322],
#        [0.13530969],
#        [0.14233911],
#        [0.01511027],
#        [0.08620669],
#        [0.07082814],
#        [0.10666051],
#        [0.01552772],
#        [0.08347035],
#        [0.13864582],
#        [0.11592656],
#        [0.12547857],
#        [0.05689413],
#        [0.11962881],
#        [0.06214051],
#        [0.0813081 ]])

# %%
plt.scatter(y_test, y_pred, color = 'black')
plt.title('y_pred vs y_test')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.show()

# %%
regressor.score(X, y, sample_weight = None)
# Out:
# 0.04498091205466437

# %%
regressor.intercept_
# Out:
# array([0.39858831])

# %%
dataset.shape
# Out:
# (353, 6)

# %%
"""#Building the optimal Model using Backward Elimination""" 
#The backwards elimination function will give us the optimal variables from our data,
# Beta0 has x^0=1. Add a column of for the the first term of the MultiLinear Regression equation.
import statsmodels.formula.api  as sm 
#The 0th column contains only 1 in each 352 rows 
X= np.append(arr = np.ones((352,1)).astype(int), values = X, axis=1) 
X_opt= X[:,[0,1,2,3,4,5]] #Optimal X contains the highly impacted independent variables
#OLS: Oridnary Least Square Class. endog is the dependent variable, exog is the number of observations
regressor_OLS=sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary() 

#constant for Beta0, x1 and x2 are the dummy variables for state, x3 is R&D,
#x4 is Administration, x5 is the marketing spends 
#Look at the highest p-values and remove it. In this condition x2(second 
#dummy variable has the highest one (0,990)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     4.265
# Date:                Wed, 14 Apr 2021   Prob (F-statistic):            0.00221
# Time:                        15:54:05   Log-Likelihood:                 18.949
# No. Observations:                 352   AIC:                            -27.90
# Df Residuals:                     347   BIC:                            -8.579
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1758      0.090      1.950      0.052      -0.002       0.353
# x1             0.1758      0.090      1.950      0.052      -0.002       0.353
# x2          5.777e-05   3.97e-05      1.455      0.147   -2.03e-05       0.000
# x3            -0.0409      0.012     -3.358      0.001      -0.065      -0.017
# x4            -0.0007      0.002     -0.427      0.670      -0.004       0.003
# x5            -0.0020      0.002     -1.011      0.313      -0.006       0.002
# ==============================================================================
# Omnibus:                      274.019   Durbin-Watson:                   1.172
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2810.760
# Skew:                           3.410   Prob(JB):                         0.00
# Kurtosis:                      15.047   Cond. No.                     9.18e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.06e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt= X[:, [0,1,2,3,5]] 
regressor_OLS=sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary() 
#Run the three lines code and Look at the highest p-value again. First
#dummy variable, x1's p-value is 0,940. Remove this one
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     5.639
# Date:                Wed, 14 Apr 2021   Prob (F-statistic):           0.000878
# Time:                        15:55:28   Log-Likelihood:                 18.856
# No. Observations:                 352   AIC:                            -29.71
# Df Residuals:                     348   BIC:                            -14.26
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1401      0.034      4.165      0.000       0.074       0.206
# x1             0.1401      0.034      4.165      0.000       0.074       0.206
# x2          5.703e-05   3.96e-05      1.439      0.151   -2.09e-05       0.000
# x3            -0.0407      0.012     -3.347      0.001      -0.065      -0.017
# x4            -0.0019      0.002     -0.983      0.326      -0.006       0.002
# ==============================================================================
# Omnibus:                      274.224   Durbin-Watson:                   1.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2816.991
# Skew:                           3.413   Prob(JB):                         0.00
# Kurtosis:                      15.061   Cond. No.                     4.64e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.04e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt= X[:, [0,1,2,3]] 
regressor_OLS=sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary() 
#Run the three lines code again and Look at the highest p-value again. Admin
#spends (x2) has the highest p-value (0,602). Remove this one.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     7.976
# Date:                Wed, 14 Apr 2021   Prob (F-statistic):           0.000410
# Time:                        15:56:12   Log-Likelihood:                 18.368
# No. Observations:                 352   AIC:                            -30.74
# Df Residuals:                     349   BIC:                            -19.14
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1179      0.025      4.735      0.000       0.069       0.167
# x1             0.1179      0.025      4.735      0.000       0.069       0.167
# x2          5.057e-05   3.91e-05      1.294      0.196   -2.63e-05       0.000
# x3            -0.0366      0.011     -3.205      0.001      -0.059      -0.014
# ==============================================================================
# Omnibus:                      275.607   Durbin-Watson:                   1.179
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2877.313
# Skew:                           3.429   Prob(JB):                         0.00
# Kurtosis:                      15.212   Cond. No.                     2.61e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.54e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt= X[:, [0,1,3]] 
regressor_OLS=sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary() 
#Run the three lines code again and Look at the highest p-value again. Admin
#spends (x2) has the highest p-value (0,06). It depends on the significance 
#level determined. If your significance level is 0.05, it needs to remove 
#this one
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     14.25
# Date:                Wed, 14 Apr 2021   Prob (F-statistic):           0.000188
# Time:                        16:00:38   Log-Likelihood:                 17.525
# No. Observations:                 352   AIC:                            -31.05
# Df Residuals:                     350   BIC:                            -23.32
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1306      0.023      5.709      0.000       0.086       0.176
# x1             0.1306      0.023      5.709      0.000       0.086       0.176
# x2            -0.0244      0.006     -3.775      0.000      -0.037      -0.012
# ==============================================================================
# Omnibus:                      277.448   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2937.477
# Skew:                           3.456   Prob(JB):                         0.00
# Kurtosis:                      15.350   Cond. No.                     1.52e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.91e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_opt= X[:, [0,3]] 
regressor_OLS=sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary() 
#That's it. We can see the highest impact variable is R&D spending in profit
#of these startups...
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     14.25
# Date:                Wed, 14 Apr 2021   Prob (F-statistic):           0.000188
# Time:                        16:00:52   Log-Likelihood:                 17.525
# No. Observations:                 352   AIC:                            -31.05
# Df Residuals:                     350   BIC:                            -23.32
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2612      0.046      5.709      0.000       0.171       0.351
# x1            -0.0244      0.006     -3.775      0.000      -0.037      -0.012
# ==============================================================================
# Omnibus:                      277.448   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2937.477
# Skew:                           3.456   Prob(JB):                         0.00
# Kurtosis:                      15.350   Cond. No.                         26.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Multiple Linear Regression Model 
#We will on modelling how R&D, Administration and Marketing Spending and the state will
#influence the profit of a company. There are 50 startups data in dataset.

#1 Importing the libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

#2 Importing the dataset: 
dataset = pd.read_csv(r'C:\Users\shubh\Desktop\IITM\Courses\Sem 2\ML in civil eng\term paper\vehicularemission_modified2.csv')
#Y: dependent variable vector
#In the first run X's type is object due to the different types of independent variables. 
#State column contains categorical variables
X = dataset.iloc[1:,[0,1,3]].values.astype(float)
y = dataset.iloc[1:,6:7].values.astype(float)

#3 Encoding the categorical variables: 
#from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#labelencoder_X = LabelEncoder() #Change the text into numbers 0,1,2
#X[: ,3]= labelencoder_X.fit_transform(X[: ,3])
#onehotencoder= OneHotEncoder(categorical_features=[3])
#turn the numbers to dummy variables. Each column represents one state
#Compare the X and dataset tables to understand the relationship between the state and the columns 
#X= onehotencoder.fit_transform(X).toarray()

#4 Avoid the dummy variables trap
#Delete the first column represent the California 
#X= X[:, 1:]

#5 Splitting the dataset into the Training and Test dataset
#train_set_split: Split arrays or matrices into random train and test subsets
##random_state değeri sonuçların her seferinde aynı çıkmasını sağlamak için kullanılıyor.
#%20 of the dataset to the test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=0)

#6 Fit multiple Linear Regression model to our Train set
from sklearn.linear_model import LinearRegression
#Create an object called regressor in the LinearRegression class...
regressor = LinearRegression()
#Fit the linear regression model to the training set... We use the fit method
#the arguments of the fit method will be training sets 
regressor.fit(X_train,y_train)

#7 Predicting the Test set results: 
y_pred= regressor.predict(X_test)
y_pred
# Out:
# array([[-4.87867952e-02],
#        [ 1.03837771e-01],
#        [ 1.78948563e-01],
#        [ 1.21161387e-01],
#        [ 9.75150340e-02],
#        [ 7.81682407e-02],
#        [ 1.28729450e-01],
#        [ 8.22145968e-02],
#        [-2.14738913e-02],
#        [ 1.33300455e-01],
#        [ 1.92099221e-01],
#        [ 2.94853654e-02],
#        [ 7.81682407e-02],
#        [ 1.04722759e-01],
#        [ 1.36208621e-01],
#        [ 7.98879233e-03],
#        [-1.13580010e-02],
#        [ 2.80424551e-03],
#        [ 3.18550059e-01],
#        [ 1.76925385e-01],
#        [ 1.35197032e-01],
#        [ 1.51995998e-01],
#        [ 2.26817040e-05],
#        [ 1.19085468e-02],
#        [ 1.14838649e-01],
#        [-9.88907330e-04],
#        [ 2.57868577e-02],
#        [ 4.66823789e-02],
#        [ 1.10918895e-01],
#        [ 4.82742358e-03],
#        [-1.02198103e-02],
#        [ 1.43542947e-01],
#        [ 8.44909782e-02],
#        [-1.23695900e-02],
#        [ 2.20930120e-01],
#        [-1.94507133e-02],
#        [ 1.74902207e-01],
#        [ 1.53532236e-01],
#        [ 3.94746540e-02],
#        [ 2.88216248e-02],
#        [ 1.04596157e-01],
#        [-3.13868705e-03],
#        [ 1.41266566e-01],
#        [ 3.94746540e-02],
#        [ 6.01808849e-02],
#        [ 1.42404756e-01],
#        [-1.94507133e-02],
#        [ 2.01330124e-01],
#        [ 7.23199533e-02],
#        [ 3.10203159e-01],
#        [ 1.16861827e-01],
#        [ 1.31150675e-01],
#        [ 1.85018098e-01],
#        [-2.94400019e-02],
#        [ 1.26219332e-01],
#        [ 2.80424551e-03],
#        [ 2.80424551e-03],
#        [ 2.51858059e-02],
#        [ 1.30265688e-01],
#        [ 1.04849361e-01],
#        [ 9.56184575e-02],
#        [ 2.73355856e-02],
#        [ 2.74621873e-02],
#        [ 1.02699581e-01],
#        [ 1.45439524e-01],
#        [ 1.14838649e-01],
#        [ 1.50699156e-02],
#        [ 2.93084716e-03],
#        [ 7.02967752e-02],
#        [-2.95666036e-02],
#        [ 6.50175832e-02]])

# %%
regressor.score(X,y)
# Out:
# 0.1178416394274957

# %%
#Logistic Regression

#1 Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

#2 Importing the dataset
# dataset = pd.read_csv(r'C:\Users\shubh\Desktop\IITM\Courses\Sem 2\ML in civil eng\term paper\CE6051- vehicular emission data set - Sheet12.csv')
dataset = pd.read_csv(r'C:\Users\shubh\Desktop\IITM\Courses\Sem 2\ML in civil eng\term paper\vehicularemission_modified2_PM.csv')
X = dataset.iloc[1:,0:5].values.astype(float)
y = dataset.iloc[1:,5:6].values.astype(float)

#3 selecting training dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
model = LogisticRegression(solver='liblinear',random_state=0)
model.fit(X_train, y_train)
# Out:
# C:\Users\shubh\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-d4a0c18be5b0> in <module>()
#       1 model = LogisticRegression(solver='liblinear',random_state=0)
# ----> 2 model.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1219         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
#    1220                          order="C")
# -> 1221         check_classification_targets(y)
#    1222         self.classes_ = np.unique(y)
#    1223         n_samples, n_features = X.shape
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     169     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     170                       'multilabel-indicator', 'multilabel-sequences']:
# --> 171         raise ValueError("Unknown label type: %r" % y_type)
#     172
#     173
#
# ValueError: Unknown label type: 'continuous'

# %%
y_pred= model.predict(X_test)
y_pred
# Out:
# array([ 2., 20., 20., 20., 17., 17., 20., 17., 17., 20., 20., 17., 17.,
#        17., 20., 17., 17., 17., 20., 20., 17., 17.,  2., 17., 17., 17.,
#        24., 17., 20., 17., 17., 20., 20., 17., 20., 17., 20., 20., 17.,
#         2., 17., 17., 20., 17., 17., 20., 17., 20., 17., 20., 20., 20.,
#        20.,  2., 20., 17., 17., 17.,  2., 20.,  2., 17., 17., 17., 20.,
#        17., 17., 17., 17., 17., 17.])
